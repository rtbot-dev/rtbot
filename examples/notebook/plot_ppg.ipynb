# %%
import matplotlib.pyplot as plt
import numpy as np

ppg=np.loadtxt("ppg.csv", skiprows=1, delimiter=',')
peak=np.loadtxt("peak.txt", usecols=[1,2])
plt.figure(figsize=(10,5),dpi=200)
plt.plot(ppg[:,0], -ppg[:,1])
plt.plot(peak[:,0]/1000, peak[:,1], 'o')
